# %%
# import numpy as np
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# import matplotlib.pyplot as plt
     
# from google.colab import drive
# drive.mount('/content/drive/', force_remount=True)

# # dataset_path = '/content/drive/MyDrive/Ct_dataset/'  
# dataset1 = "/content/drive/MyDrive/segmentation/i1/"
# dataset2 = "/content/drive/MyDrive/segmentation/m1/"
# def my_image_mask_generator(image_data_generator, mask_data_generator):
#     train_generator = zip(image_data_generator, mask_data_generator)
#     for (img, mask) in train_generator:
#         yield (img, mask)


# image_size = (224,224)
# batch_size = 32
# # seed = 909

# # seed = 909 # (IMPORTANT) to transform image and corresponding mask with same augmentation parameter.
# SEED = 100

# image_data_generator = ImageDataGenerator(
#     width_shift_range = 0.1,
#     height_shift_range = 0.1,
#     rotation_range = 10,
#     zoom_range = 0.1
# ).flow_from_directory(dataset1, batch_size = 32, target_size = (224, 224), seed = SEED)

# mask_data_generator = ImageDataGenerator(
#     width_shift_range = 0.1,
#     height_shift_range = 0.1,
#     rotation_range = 10,
#     zoom_range = 0.1
# ).flow_from_directory(dataset1, batch_size = 32, target_size = (224, 224), seed = SEED)


# my_generator = my_image_mask_generator(image_data_generator, mask_data_generator)
# Out:
# Mounted at /content/drive/
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-4096cf8538bb> in <module>
#      25 SEED = 100
#      26
# ---> 27 image_data_generator = ImageDataGenerator(
#      28     width_shift_range = 0.1,
#      29     height_shift_range = 0.1,
#
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1467             and `y` is a numpy array of corresponding labels.
#    1468     """
# -> 1469     return DirectoryIterator(
#    1470         directory,
#    1471         self,
#
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/image.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     505     if not classes:
#     506       classes = []
# --> 507       for subdir in sorted(os.listdir(directory)):
#     508         if os.path.isdir(os.path.join(directory, subdir)):
#     509           classes.append(subdir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/segmentation/i1/'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)

data_gen_args = dict(featurewise_center=True,
                     featurewise_std_normalization=True,
                     rotation_range=90,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     zoom_range=0.2)
image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen = ImageDataGenerator(**data_gen_args)
# Provide the same seed and keyword arguments to the fit and flow methods
seed = 1
# image_datagen.fit(augment=True, seed=seed)
# mask_datagen.fit(augment=True, seed=seed)
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)


image_generator = train_datagen.flow_from_directory(
    '/content/drive/MyDrive/segmentation/im/',
    class_mode=None,
    seed=seed)
mask_generator = train_datagen.flow_from_directory(
    '/content/drive/MyDrive/segmentation/ma/',
    class_mode=None,
    seed=seed)
# combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)
# Out:
# Mounted at /content/drive/
# Found 1753 images belonging to 1 classes.
# Found 1753 images belonging to 1 classes.

# %%
from keras.losses import binary_crossentropy
from keras import backend as K
import tensorflow as tf

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

### bce_dice_loss = binary_crossentropy_loss + dice_loss
def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
from keras.layers import Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, Dropout, Input, BatchNormalization
from keras import optimizers
from keras.models import Model

IMG_DIM = (224,224,3)

def conv2d_block( input_tensor, n_filters, kernel_size = (3,3), name="contraction"):
  "Add 2 conv layer"
  x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu", name=name+'_1')(input_tensor)
  
  x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu",name=name+'_2')(x)
  return x
  

inp = Input( shape=IMG_DIM )

d1 = conv2d_block( inp, 64, name="contraction_1")
p1 = MaxPooling2D( pool_size=(2,2), strides=(2,2))(d1)
p1 = BatchNormalization(momentum=0.8)(p1)
p1 = Dropout(0.1)(p1)

d2 = conv2d_block( p1, 128, name="contraction_2_1" )
p2 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d2)
p2 = BatchNormalization(momentum=0.8)(p2)
p2 = Dropout(0.1)(p2)

d3 = conv2d_block( p2, 256, name="contraction_3_1")
p3 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d3)
p3 = BatchNormalization(momentum=0.8)(p3)
p3 = Dropout(0.1)(p3)

d4 = conv2d_block(p3,512, name="contraction_4_1")
p4 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d4)
p4 = BatchNormalization(momentum=0.8)(p4)
p4 = Dropout(0.1)(p4)

d5 = conv2d_block(p4,512, name="contraction_5_1")

u1 = Conv2DTranspose(512, (3, 3), strides = (2, 2), padding = 'same')(d5)
u1 = concatenate([u1,d4])
u1 = Dropout(0.1)(u1)
c1 = conv2d_block(u1, 512, name="expansion_1")

u2 = Conv2DTranspose(256, (3, 3), strides = (2, 2), padding = 'same')(c1)
u2 = concatenate([u2,d3])
u2 = Dropout(0.1)(u2)
c2 = conv2d_block(u2, 256, name="expansion_2")

u3 = Conv2DTranspose(128, (3, 3), strides = (2, 2), padding = 'same')(c2)
u3 = concatenate([u3,d2])
u3 = Dropout(0.1)(u3)
c3 = conv2d_block(u3, 128, name="expansion_3")

u4 = Conv2DTranspose(64, (3, 3), strides = (2, 2), padding = 'same')(c3)
u4 = concatenate([u4,d1])
u4 = Dropout(0.1)(u4)
c4 = conv2d_block(u4,64, name="expansion_4")

out = Conv2D(1, (1,1), name="output", activation='sigmoid')(c4)

model = Model( inp, out )
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  contraction_1_1 (Conv2D)       (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  contraction_1_2 (Conv2D)       (None, 224, 224, 64  36928       ['contraction_1_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 64  0           ['contraction_1_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['max_pooling2d[0][0]']
#  alization)                     )
#
#  dropout (Dropout)              (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  contraction_2_1_1 (Conv2D)     (None, 112, 112, 12  73856       ['dropout[0][0]']
#                                 8)
#
#  contraction_2_1_2 (Conv2D)     (None, 112, 112, 12  147584      ['contraction_2_1_1[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0          ['contraction_2_1_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 128)  512        ['max_pooling2d_1[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 56, 56, 128)  0           ['batch_normalization_1[0][0]']
#
#  contraction_3_1_1 (Conv2D)     (None, 56, 56, 256)  295168      ['dropout_1[0][0]']
#
#  contraction_3_1_2 (Conv2D)     (None, 56, 56, 256)  590080      ['contraction_3_1_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0          ['contraction_3_1_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 256)  1024       ['max_pooling2d_2[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 28, 28, 256)  0           ['batch_normalization_2[0][0]']
#
#  contraction_4_1_1 (Conv2D)     (None, 28, 28, 512)  1180160     ['dropout_2[0][0]']
#
#  contraction_4_1_2 (Conv2D)     (None, 28, 28, 512)  2359808     ['contraction_4_1_1[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0          ['contraction_4_1_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 14, 14, 512)  2048       ['max_pooling2d_3[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 14, 14, 512)  0           ['batch_normalization_3[0][0]']
#
#  contraction_5_1_1 (Conv2D)     (None, 14, 14, 512)  2359808     ['dropout_3[0][0]']
#
#  contraction_5_1_2 (Conv2D)     (None, 14, 14, 512)  2359808     ['contraction_5_1_1[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 28, 28, 512)  2359808    ['contraction_5_1_2[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 28, 28, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'contraction_4_1_2[0][0]']
#
#  dropout_4 (Dropout)            (None, 28, 28, 1024  0           ['concatenate[0][0]']
#                                 )
#
#  expansion_1_1 (Conv2D)         (None, 28, 28, 512)  4719104     ['dropout_4[0][0]']
#
#  expansion_1_2 (Conv2D)         (None, 28, 28, 512)  2359808     ['expansion_1_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 56, 56, 256)  1179904    ['expansion_1_2[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'contraction_3_1_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 56, 56, 512)  0           ['concatenate_1[0][0]']
#
#  expansion_2_1 (Conv2D)         (None, 56, 56, 256)  1179904     ['dropout_5[0][0]']
#
#  expansion_2_2 (Conv2D)         (None, 56, 56, 256)  590080      ['expansion_2_1[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 112, 112, 12  295040     ['expansion_2_2[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 112, 112, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'contraction_2_1_2[0][0]']
#
#  dropout_6 (Dropout)            (None, 112, 112, 25  0           ['concatenate_2[0][0]']
#                                 6)
#
#  expansion_3_1 (Conv2D)         (None, 112, 112, 12  295040      ['dropout_6[0][0]']
#                                 8)
#
#  expansion_3_2 (Conv2D)         (None, 112, 112, 12  147584      ['expansion_3_1[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 224, 224, 64  73792      ['expansion_3_2[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 224, 224, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'contraction_1_2[0][0]']
#
#  dropout_7 (Dropout)            (None, 224, 224, 12  0           ['concatenate_3[0][0]']
#                                 8)
#
#  expansion_4_1 (Conv2D)         (None, 224, 224, 64  73792       ['dropout_7[0][0]']
#                                 )
#
#  expansion_4_2 (Conv2D)         (None, 224, 224, 64  36928       ['expansion_4_1[0][0]']
#                                 )
#
#  output (Conv2D)                (None, 224, 224, 1)  65          ['expansion_4_2[0][0]']
#
# ==================================================================================================
# Total params: 22,719,681
# Trainable params: 22,717,761
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, 2, strides=2, padding="valid")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    # print(s1.shape, s2.shape, s3.shape, s4.shape)
    # print(p1.shape, p2.shape, p3.shape, p4.shape)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="valid", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (224, 224, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_27 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_213 (Conv2D)            (None, 224, 224, 64  1792        ['input_27[0][0]']
#                                 )
#
#  batch_normalization_250 (Batch  (None, 224, 224, 64  256        ['conv2d_213[0][0]']
#  Normalization)                 )
#
#  activation_206 (Activation)    (None, 224, 224, 64  0           ['batch_normalization_250[0][0]']
#                                 )
#
#  conv2d_214 (Conv2D)            (None, 224, 224, 64  36928       ['activation_206[0][0]']
#                                 )
#
#  batch_normalization_251 (Batch  (None, 224, 224, 64  256        ['conv2d_214[0][0]']
#  Normalization)                 )
#
#  activation_207 (Activation)    (None, 224, 224, 64  0           ['batch_normalization_251[0][0]']
#                                 )
#
#  max_pooling2d_104 (MaxPooling2  (None, 112, 112, 64  0          ['activation_207[0][0]']
#  D)                             )
#
#  conv2d_215 (Conv2D)            (None, 112, 112, 12  73856       ['max_pooling2d_104[0][0]']
#                                 8)
#
#  batch_normalization_252 (Batch  (None, 112, 112, 12  512        ['conv2d_215[0][0]']
#  Normalization)                 8)
#
#  activation_208 (Activation)    (None, 112, 112, 12  0           ['batch_normalization_252[0][0]']
#                                 8)
#
#  conv2d_216 (Conv2D)            (None, 112, 112, 12  147584      ['activation_208[0][0]']
#                                 8)
#
#  batch_normalization_253 (Batch  (None, 112, 112, 12  512        ['conv2d_216[0][0]']
#  Normalization)                 8)
#
#  activation_209 (Activation)    (None, 112, 112, 12  0           ['batch_normalization_253[0][0]']
#                                 8)
#
#  max_pooling2d_105 (MaxPooling2  (None, 56, 56, 128)  0          ['activation_209[0][0]']
#  D)
#
#  conv2d_217 (Conv2D)            (None, 56, 56, 256)  295168      ['max_pooling2d_105[0][0]']
#
#  batch_normalization_254 (Batch  (None, 56, 56, 256)  1024       ['conv2d_217[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 56, 56, 256)  0           ['batch_normalization_254[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 56, 56, 256)  590080      ['activation_210[0][0]']
#
#  batch_normalization_255 (Batch  (None, 56, 56, 256)  1024       ['conv2d_218[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 56, 56, 256)  0           ['batch_normalization_255[0][0]']
#
#  max_pooling2d_106 (MaxPooling2  (None, 28, 28, 256)  0          ['activation_211[0][0]']
#  D)
#
#  conv2d_219 (Conv2D)            (None, 28, 28, 512)  1180160     ['max_pooling2d_106[0][0]']
#
#  batch_normalization_256 (Batch  (None, 28, 28, 512)  2048       ['conv2d_219[0][0]']
#  Normalization)
#
#  activation_212 (Activation)    (None, 28, 28, 512)  0           ['batch_normalization_256[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 28, 28, 512)  2359808     ['activation_212[0][0]']
#
#  batch_normalization_257 (Batch  (None, 28, 28, 512)  2048       ['conv2d_220[0][0]']
#  Normalization)
#
#  activation_213 (Activation)    (None, 28, 28, 512)  0           ['batch_normalization_257[0][0]']
#
#  max_pooling2d_107 (MaxPooling2  (None, 14, 14, 512)  0          ['activation_213[0][0]']
#  D)
#
#  conv2d_221 (Conv2D)            (None, 14, 14, 1024  4719616     ['max_pooling2d_107[0][0]']
#                                 )
#
#  batch_normalization_258 (Batch  (None, 14, 14, 1024  4096       ['conv2d_221[0][0]']
#  Normalization)                 )
#
#  activation_214 (Activation)    (None, 14, 14, 1024  0           ['batch_normalization_258[0][0]']
#                                 )
#
#  conv2d_222 (Conv2D)            (None, 14, 14, 1024  9438208     ['activation_214[0][0]']
#                                 )
#
#  batch_normalization_259 (Batch  (None, 14, 14, 1024  4096       ['conv2d_222[0][0]']
#  Normalization)                 )
#
#  activation_215 (Activation)    (None, 14, 14, 1024  0           ['batch_normalization_259[0][0]']
#                                 )
#
#  conv2d_transpose_68 (Conv2DTra  (None, 28, 28, 512)  2097664    ['activation_215[0][0]']
#  nspose)
#
#  concatenate_68 (Concatenate)   (None, 28, 28, 1024  0           ['conv2d_transpose_68[0][0]',
#                                 )                                 'activation_213[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 28, 28, 512)  4719104     ['concatenate_68[0][0]']
#
#  batch_normalization_260 (Batch  (None, 28, 28, 512)  2048       ['conv2d_223[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 28, 28, 512)  0           ['batch_normalization_260[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 28, 28, 512)  2359808     ['activation_216[0][0]']
#
#  batch_normalization_261 (Batch  (None, 28, 28, 512)  2048       ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_217 (Activation)    (None, 28, 28, 512)  0           ['batch_normalization_261[0][0]']
#
#  conv2d_transpose_69 (Conv2DTra  (None, 56, 56, 256)  524544     ['activation_217[0][0]']
#  nspose)
#
#  concatenate_69 (Concatenate)   (None, 56, 56, 512)  0           ['conv2d_transpose_69[0][0]',
#                                                                   'activation_211[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 56, 56, 256)  1179904     ['concatenate_69[0][0]']
#
#  batch_normalization_262 (Batch  (None, 56, 56, 256)  1024       ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 56, 56, 256)  0           ['batch_normalization_262[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 56, 56, 256)  590080      ['activation_218[0][0]']
#
#  batch_normalization_263 (Batch  (None, 56, 56, 256)  1024       ['conv2d_226[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (None, 56, 56, 256)  0           ['batch_normalization_263[0][0]']
#
#  conv2d_transpose_70 (Conv2DTra  (None, 112, 112, 12  131200     ['activation_219[0][0]']
#  nspose)                        8)
#
#  concatenate_70 (Concatenate)   (None, 112, 112, 25  0           ['conv2d_transpose_70[0][0]',
#                                 6)                                'activation_209[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 112, 112, 12  295040      ['concatenate_70[0][0]']
#                                 8)
#
#  batch_normalization_264 (Batch  (None, 112, 112, 12  512        ['conv2d_227[0][0]']
#  Normalization)                 8)
#
#  activation_220 (Activation)    (None, 112, 112, 12  0           ['batch_normalization_264[0][0]']
#                                 8)
#
#  conv2d_228 (Conv2D)            (None, 112, 112, 12  147584      ['activation_220[0][0]']
#                                 8)
#
#  batch_normalization_265 (Batch  (None, 112, 112, 12  512        ['conv2d_228[0][0]']
#  Normalization)                 8)
#
#  activation_221 (Activation)    (None, 112, 112, 12  0           ['batch_normalization_265[0][0]']
#                                 8)
#
#  conv2d_transpose_71 (Conv2DTra  (None, 224, 224, 64  32832      ['activation_221[0][0]']
#  nspose)                        )
#
#  concatenate_71 (Concatenate)   (None, 224, 224, 12  0           ['conv2d_transpose_71[0][0]',
#                                 8)                                'activation_207[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 224, 224, 64  73792       ['concatenate_71[0][0]']
#                                 )
#
#  batch_normalization_266 (Batch  (None, 224, 224, 64  256        ['conv2d_229[0][0]']
#  Normalization)                 )
#
#  activation_222 (Activation)    (None, 224, 224, 64  0           ['batch_normalization_266[0][0]']
#                                 )
#
#  conv2d_230 (Conv2D)            (None, 224, 224, 64  36928       ['activation_222[0][0]']
#                                 )
#
#  batch_normalization_267 (Batch  (None, 224, 224, 64  256        ['conv2d_230[0][0]']
#  Normalization)                 )
#
#  activation_223 (Activation)    (None, 224, 224, 64  0           ['batch_normalization_267[0][0]']
#                                 )
#
#  conv2d_231 (Conv2D)            (None, 224, 224, 1)  65          ['activation_223[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
import numpy as np

def get_iou_vector(A, B):
    t = A>0
    p = B>0
    intersection = np.logical_and(t,p)
    union = np.logical_or(t,p)
    iou = (np.sum(intersection) + 1e-10 )/ (np.sum(union) + 1e-10)
    return iou

def iou_metric(label, pred):
    return tf.py_function(get_iou_vector, [label, pred>0.5], tf.float64)

model.compile(optimizer=optimizers.Adam(learning_rate=1e-3), 
             loss=bce_dice_loss, metrics=['accuracy',iou_metric])

# %%
model.fit(train_generator,epochs=32,verbose=1)
# model.fit(x=train_batches, steps_per_epoch=len(train_batches), validation_data=validation_batches, validation_steps=len(validation_batches), epochs=20, verbose=1 )
